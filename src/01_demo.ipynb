# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from OmekaS.github import GitHubApiClient
from OmekaS.notion import NotionApiClient

# %%
GitHubApiClient.run()
# Out:
# 100%|██████████| 98/98 [01:50<00:00,  1.12s/it]

# %%
# NotionApiClient.run(limit=10)
NotionApiClient.run()
# Out:
# 100%|██████████| 89/89 [02:34<00:00,  1.73s/it]
